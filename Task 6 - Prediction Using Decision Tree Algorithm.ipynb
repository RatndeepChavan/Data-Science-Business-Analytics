# %% [markdown]
# # Author : Ratndeep Chavan
# # Organization : The Spark Foundation (GRIP)
# # Internship : Data Science & Business Analytics
# # Task 6 : Prediction Using Decision Tree Algorithm (EDA)
# # Task Level : Intermediate
# ## Task To perform : Create the decision tree classifier and visualize it graphically

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

tn = pd.read_csv('Iris.csv')
tn.shape
# Out:
# (150, 6)

# %%
tn.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
# My personal function

from My_functions import details
details(tn)
# Out:
#               Counts Missing  Missing percent Unique    Dtype         Mode  \
# Id               150       0              0.0    150    int64            1
# SepalLengthCm    150       0              0.0     35  float64            5
# SepalWidthCm     150       0              0.0     23  float64            3
# PetalLengthCm    150       0              0.0     43  float64          1.5
# PetalWidthCm     150       0              0.0     22  float64          0.2
# Species          150       0              0.0      3   object  Iris-setosa
#
#                Min  Max     Mean Median    25%   50%     75%       Std
# Id               1  150     75.5   75.5  38.25  75.5  112.75   43.4454
# SepalLengthCm  4.3  7.9  5.84333    5.8    5.1   5.8     6.4  0.828066
# SepalWidthCm     2  4.4    3.054      3    2.8     3     3.3  0.433594
# PetalLengthCm    1  6.9  3.75867   4.35    1.6  4.35     5.1   1.76442
# PetalWidthCm   0.1  2.5  1.19867    1.3    0.3   1.3     1.8  0.763161
# ...

# %%
# My personal function

from My_functions import num
num(tn.drop(['Id','Species'], axis=1), uni=3)

# %% [markdown]
# ### Data in very good condition and ready to use for model building

# %%
from sklearn import tree
m = tree.DecisionTreeClassifier(random_state=8)
m.fit(tn.drop(['Id','Species'], axis=1), tn['Species'])
# Out:
# DecisionTreeClassifier(random_state=8)

# %%
# Visualizing the decision tree

plt.figure(figsize=(20,10))
tree.plot_tree(m, filled=True)
# Out:
# [Text(558.0, 498.3, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 407.70000000000005, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 407.70000000000005, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 317.1, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 226.5, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 135.89999999999998, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 226.5, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 135.89999999999998, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# ### This is the final Decision Tree
